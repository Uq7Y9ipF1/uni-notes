# %% [markdown]
# # Лабораторная 7:
#
# ## Цель
# Изучение PostgreSQL.

# %%
import psycopg2
def execute(q):
    conn = psycopg2.connect(host='localhost', database='students', user='postgres', password='pwd')
    cur = conn.cursor()
    cur.execute(q)
    r = cur.fetchall() if q.strip().upper().startswith('SELECT') else cur.rowcount
    conn.commit(); conn.close()
    return r

# %% [markdown]
# ## Задания

# %%
q = '''SELECT COUNT(*) FROM student;'''
print(execute(q))

# %% [markdown]
# ## Варианты

# %% [markdown]
# ### Вариант 0
#
# 0.25
# Повторим предыдущую транзакцию, только вместе команды COMMIT выполним команду ROLLBACK.
# BEGIN;
# UPDATE employment
# SET wage_rate = wage_rate * 1.10;
# ROLLBACK;
# Убедимся в том, что значения не были изменены в результате транзакции.
# Практическая часть
# Задание 1.
# Для глубокого анализа данного задания...

# %%
# Вариант 0
q = '''-- SQL для варианта 0
'''

# %% [markdown]
# ### Вариант 1
#
# 1.50...

# %%
# Вариант 1
q = '''-- SQL для варианта 1
'''

# %% [markdown]
# ## Математика
#
# - Селекция σ
# - Проекция π
# - Соединение ⋈
